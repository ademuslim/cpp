# %% [markdown]
# <a href="https://colab.research.google.com/github/amuslim12/cpp/blob/main/tugas_p10_mk_pengolahan_citra_ade_muslim_312010147.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Tugas MK Pengolahan Citra
# ###### Nama : Ade Muslim
# ###### NIM  : 312010147

# %%
import numpy as np
import mahotas
import mahotas.demos

# %%
from mahotas.thresholding import soft_threshold
from matplotlib import pyplot as plt
from os import path

# %%
f = mahotas.demos.load('luispedro',as_grey=True)
f = f[:256,:256]
plt.gray ()
#menampilkan gambar
print("Fraction of zeros in original image : {0}",format(np.mean (f==0)))
plt.imshow(f)
plt.show()
# Out:
# Fraction of zeros in original image : {0} 0.0

# %%
# !pip install mahotas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.7 MB 4.7 MB/s
# ...
